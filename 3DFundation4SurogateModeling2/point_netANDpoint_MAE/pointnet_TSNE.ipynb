# %% [markdown]
# # **Point Net - Classification**

# %%
import os
import re
from glob import glob
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchmetrics
from torchmetrics.classification import MulticlassMatthewsCorrCoef
import open3d as o3

from open3d.web_visualizer import draw # for non Colab
import os, os.path as osp

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [Open3D INFO] Resetting default logger to print to terminal.

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cuda'

# %% [markdown]
# ## Now: feature extraction of the foils

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
import warnings
from models.point_net.point_net import PointNetClassHead
from shapely.geometry import Polygon
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.colors import LinearSegmentedColormap, ListedColormap, BoundaryNorm

# from analyze_pointnet_backbone import analyze_pointnet_backbone
from models.point_net.analyze_pointnet_backbone import analyze_pointnet_backbone
plots = True

# %% [markdown]
# ### cls_model_35

# %%
out35 = analyze_pointnet_backbone('models/point_net/trained_models/cls_focal_clr/cls_model_35.pth',DEVICE, plots)
# Out:
# [cls_model_35] Model loaded from: models/point_net/trained_models/cls_focal_clr/cls_model_35.pth
# [cls_model_35] Collected features: X=(1000, 1024), labels=(1000,)
# [cls_model_35] Saved extracted features to:
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_features.csv
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_features.parquet
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.001s...
# [t-SNE] Computed neighbors for 1000 samples in 0.024s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.000118
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.315052
# [t-SNE] KL divergence after 1000 iterations: 0.404395
# [cls_model_35] t-SNE computed: X2=(1000, 2)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_tsne_embeddings.png
# [save] cls_model_35_tsne_embeddings.npy → c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_tsne_embeddings.npy
# [cls_model_35] DBSCAN: clusters=3, noise=0 (eps=3.0, min_samples=10)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_tsne_dbscan.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_tsne_area.png
# [cls_model_35] NACA kinds — 4-digit: 489, 5-digit: 511, unknown: 0
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_tsne_camber.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_35\cls_model_35_tsne_thickness.png

# %% [markdown]
# ### cls_model_37

# %%
out37 = analyze_pointnet_backbone('models/point_net/trained_models/cls_focal_clr/cls_model_37.pth',DEVICE, plots)
# Out:
# [cls_model_37] Model loaded from: models/point_net/trained_models/cls_focal_clr/cls_model_37.pth
# [cls_model_37] Collected features: X=(1000, 1024), labels=(1000,)
# [cls_model_37] Saved extracted features to:
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_features.csv
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_features.parquet
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.000s...
# [t-SNE] Computed neighbors for 1000 samples in 0.010s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.000334
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.012428
# [t-SNE] KL divergence after 1000 iterations: 0.496296
# [cls_model_37] t-SNE computed: X2=(1000, 2)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_tsne_embeddings.png
# [save] cls_model_37_tsne_embeddings.npy → c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_tsne_embeddings.npy
# [cls_model_37] DBSCAN: clusters=2, noise=0 (eps=3.0, min_samples=10)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_tsne_dbscan.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_tsne_area.png
# [cls_model_37] NACA kinds — 4-digit: 489, 5-digit: 511, unknown: 0
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_tsne_camber.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_37\cls_model_37_tsne_thickness.png

# %% [markdown]
# ### cls_model_38

# %%
out38 = analyze_pointnet_backbone('models/point_net/trained_models/cls_focal_clr/cls_model_38.pth',DEVICE, plots)
# Out:
# [cls_model_38] Model loaded from: models/point_net/trained_models/cls_focal_clr/cls_model_38.pth
# [cls_model_38] Collected features: X=(1000, 1024), labels=(1000,)
# [cls_model_38] Saved extracted features to:
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_features.csv
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_features.parquet
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.000s...
# [t-SNE] Computed neighbors for 1000 samples in 0.020s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.000511
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.678707
# [t-SNE] KL divergence after 1000 iterations: 0.488568
# [cls_model_38] t-SNE computed: X2=(1000, 2)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_tsne_embeddings.png
# [save] cls_model_38_tsne_embeddings.npy → c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_tsne_embeddings.npy
# [cls_model_38] DBSCAN: clusters=2, noise=0 (eps=3.0, min_samples=10)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_tsne_dbscan.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_tsne_area.png
# [cls_model_38] NACA kinds — 4-digit: 489, 5-digit: 511, unknown: 0
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_tsne_camber.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_38\cls_model_38_tsne_thickness.png

# %% [markdown]
# ### cls_model_15

# %%
out15 = analyze_pointnet_backbone('models/point_net/trained_models/cls_focal/cls_model_15.pth',DEVICE, plots)
# Out:
# [cls_model_15] Model loaded from: models/point_net/trained_models/cls_focal/cls_model_15.pth
# [cls_model_15] Collected features: X=(1000, 1024), labels=(1000,)
# [cls_model_15] Saved extracted features to:
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_features.csv
#   - c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_features.parquet
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.000s...
# [t-SNE] Computed neighbors for 1000 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.000289
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.198997
# [t-SNE] KL divergence after 1000 iterations: 0.635155
# [cls_model_15] t-SNE computed: X2=(1000, 2)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_tsne_embeddings.png
# [save] cls_model_15_tsne_embeddings.npy → c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_tsne_embeddings.npy
# [cls_model_15] DBSCAN: clusters=2, noise=15 (eps=3.0, min_samples=10)
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_tsne_dbscan.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_tsne_area.png
# [cls_model_15] NACA kinds — 4-digit: 489, 5-digit: 511, unknown: 0
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_tsne_camber.png
# [plot] saved c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\point_netANDpoint_MAE\extracted_features\cls_model_15\cls_model_15_tsne_thickness.png

# %%
    
# ------------------------------------------------------------------------------- t-SNE on raw (x,y) coordinates — no preprocessing
from torch.utils.data import DataLoader
from UTILS.shapenet_dataset import ShapenetDataset    
ROOT = osp.abspath("shapenet_like_out")
npoints = 10000
BATCH_SIZE = 32
test_dataset = ShapenetDataset(ROOT, npoints=npoints, split='test', classification=True, normalize=False) #already normalized in convert_to_shapenet_like, see later if we keep it like that or not
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE)    

N = len(test_dataset)
NPTS = getattr(test_dataset, "npoints", None)

# Build raw feature matrix by simple flattening of (x,y)
raw_xy = np.empty((N, 2 * NPTS), dtype=np.float32)
for i in range(N):
    pts, _ = test_dataset[i]                  # (NPTS, 3) tensor
    pts = np.asarray(pts)
    xy = pts[:, :2].reshape(-1)               # (2*NPTS,)
    raw_xy[i] = xy

tsne_raw = TSNE(
    n_components=2,
    metric='cosine',
    init='pca', # t is highly recommended to use another dimensionality reduction method (e.g. PCA for dense data or TruncatedSVD for sparse data)
    learning_rate='auto',
    perplexity=30, #  Consider selecting a value between 5 and 50
    verbose=1
)
X2_raw = tsne_raw.fit_transform(raw_xy)
print(f"[Raw (x,y) t-SNE computed: X2_raw={X2_raw.shape}")

# Plot (neutral)
plt.figure(figsize=(8, 6))
plt.scatter(X2_raw[:, 0], X2_raw[:, 1], s=7, color=(0.6, 0.6, 0.6), edgecolors='none')
plt.title(f'Raw geometry t-SNE (flattened x,y)')
plt.tight_layout()
plt.show()
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.016s...
# [t-SNE] Computed neighbors for 1000 samples in 0.078s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.027204
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.200768
# [t-SNE] KL divergence after 1000 iterations: 2.668621
# [Raw (x,y) t-SNE computed: X2_raw=(1000, 2)
