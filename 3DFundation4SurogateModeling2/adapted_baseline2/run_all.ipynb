# %%
from main2 import run_training_pipeline
models_to_run_local = [
    "GraphSAGE",
    "GUNet",
    "PointNet",
    "MLP",
]

for model in models_to_run_local:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baseline3",
        scores_dir="all_score_baseline4",
        metrics_dir="all_metrics_baseline4",
        param = 'params_pointmae',
    )
# Out:
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [30:41<00:00,  2.30s/it, train_loss=0.000137, val_loss=0.0185]
# Number of parameters: 29009.0
# Time elapsed: 1841.44 seconds
# Scores saved in: all_score_baseline4\scarce\GraphSAGE
#
# Running training for: GUNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:18:59<00:00,  5.92s/it, train_loss=0.00036, val_loss=0.0154]
# Number of parameters: 65625.0
# Time elapsed: 4739.54 seconds
# Scores saved in: all_score_baseline4\scarce\GUNet
#
# Running training for: PointNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [25:45<00:00,  1.93s/it, train_loss=0.000524, val_loss=0.0108]
# Number of parameters: 75049.0
# Time elapsed: 1545.83 seconds
# Scores saved in: all_score_baseline4\scarce\PointNet
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [12:40<00:00,  1.05it/s, train_loss=0.00013, val_loss=0.0181]
# Number of parameters: 19793.0
# Time elapsed: 760.19 seconds
# Scores saved in: all_score_baseline4\scarce\MLP

# %%
models_to_run_global = [
    "GUNetGlobal",
    "GraphSAGEGlobal",
    "PointNetGlobal",
    "MLPGlobal",
]

for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_default3",
        scores_dir="all_score_pointmae_default4",
        metrics_dir="all_metrics_pointmae_default4",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [45:31<00:00,  3.41s/it, train_loss=0.00126, val_loss=0.0126]
# Number of parameters: 144098.0
# Time elapsed: 2731.87 seconds
# Scores saved in: all_score_pointmae_default4\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [25:18<00:00,  1.90s/it, train_loss=0.000532, val_loss=0.0105]
# Number of parameters: 107482.0
# Time elapsed: 1518.98 seconds
# Scores saved in: all_score_pointmae_default4\scarce\GraphSAGEGlobal
#
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [21:59<00:00,  1.65s/it, train_loss=0.000452, val_loss=0.0236]
# Number of parameters: 153522.0
# Time elapsed: 1319.09 seconds
# Scores saved in: all_score_pointmae_default4\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [13:49<00:00,  1.04s/it, train_loss=0.00047, val_loss=0.00847]
# Number of parameters: 98266.0
# Time elapsed: 829.06 seconds
# Scores saved in: all_score_pointmae_default4\scarce\MLPGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_normalized3",
        scores_dir="all_score_pointmae_normalized4",
        metrics_dir="all_metrics_pointmae_normalized4",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_normalized/PointMAE_pretrain_normalized_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [45:37<00:00,  3.42s/it, train_loss=0.000739, val_loss=0.011]
# Number of parameters: 144098.0
# Time elapsed: 2737.92 seconds
# Scores saved in: all_score_pointmae_normalized4\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [20:33<00:00,  1.54s/it, train_loss=0.000384, val_loss=0.0144]
# Number of parameters: 107482.0
# Time elapsed: 1233.64 seconds
# Scores saved in: all_score_pointmae_normalized4\scarce\GraphSAGEGlobal
#
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [17:21<00:00,  1.30s/it, train_loss=0.000762, val_loss=0.0145]
# Number of parameters: 153522.0
# Time elapsed: 1041.37 seconds
# Scores saved in: all_score_pointmae_normalized4\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [13:41<00:00,  1.03s/it, train_loss=0.000373, val_loss=0.0172]
# Number of parameters: 98266.0
# Time elapsed: 821.18 seconds
# Scores saved in: all_score_pointmae_normalized4\scarce\MLPGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_default3",
        scores_dir="all_score_pointnet_default4",
        metrics_dir="all_metrics_pointnet_default4",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_default/cls_model_35_default_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [45:22<00:00,  3.40s/it, train_loss=0.000971, val_loss=0.0076]
# Number of parameters: 135906.0
# Time elapsed: 2722.71 seconds
# Scores saved in: all_score_pointnet_default4\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [20:29<00:00,  1.54s/it, train_loss=0.000475, val_loss=0.0126]
# Number of parameters: 99290.0
# Time elapsed: 1229.20 seconds
# Scores saved in: all_score_pointnet_default4\scarce\GraphSAGEGlobal
#
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [17:14<00:00,  1.29s/it, train_loss=0.00064, val_loss=0.00859]
# Number of parameters: 145330.0
# Time elapsed: 1034.68 seconds
# Scores saved in: all_score_pointnet_default4\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [13:36<00:00,  1.02s/it, train_loss=0.000299, val_loss=0.0104]
# Number of parameters: 90074.0
# Time elapsed: 816.87 seconds
# Scores saved in: all_score_pointnet_default4\scarce\MLPGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_normalized3",
        scores_dir="all_score_pointnet_normalized4",
        metrics_dir="all_metrics_pointnet_normalized4",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_normalized/cls_model_35_normalized_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [45:34<00:00,  3.42s/it, train_loss=0.00143, val_loss=0.00933]
# Number of parameters: 135906.0
# Time elapsed: 2734.00 seconds
# Scores saved in: all_score_pointnet_normalized4\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [20:27<00:00,  1.53s/it, train_loss=0.00063, val_loss=0.0116]
# Number of parameters: 99290.0
# Time elapsed: 1227.09 seconds
# Scores saved in: all_score_pointnet_normalized4\scarce\GraphSAGEGlobal
#
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [17:16<00:00,  1.30s/it, train_loss=0.000747, val_loss=0.00963]
# Number of parameters: 145330.0
# Time elapsed: 1036.85 seconds
# Scores saved in: all_score_pointnet_normalized4\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [13:41<00:00,  1.03s/it, train_loss=0.000412, val_loss=0.0143]
# Number of parameters: 90074.0
# Time elapsed: 821.74 seconds
# Scores saved in: all_score_pointnet_normalized4\scarce\MLPGlobal
