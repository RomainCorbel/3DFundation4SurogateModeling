# %%
from main2 import run_training_pipeline
models_to_run_local = [
    "PointNet",
    "MLP",
]

for model in models_to_run_local:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baseline3",
        scores_dir="all_score_baseline3",
        metrics_dir="all_metrics_baseline3",
        param = 'params_pointmae',
    )
# Out:
# Running training for: PointNet
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Building dataset without global features (.g will be omitted)
# 100%|██████████| 180/180 [00:43<00:00,  4.17it/s]
# 100%|██████████| 20/20 [00:12<00:00,  1.63it/s]
# 100%|██████████| 200/200 [01:57<00:00,  1.70it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\baseline3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\baseline3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\baseline3\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\baseline3\normalization
# Using GPU
# 100%|██████████| 800/800 [22:00<00:00,  1.65s/it, train_loss=0.000622, val_loss=0.0104]
# Number of parameters: 75049.0
# Time elapsed: 1320.99 seconds
# Scores saved in: all_score_baseline3\scarce\PointNet
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [16:02<00:00,  1.20s/it, train_loss=0.000132, val_loss=0.019]
# Number of parameters: 19793.0
# Time elapsed: 962.34 seconds
# Scores saved in: all_score_baseline3\scarce\MLP

# %%
models_to_run_global = [
    "PointNetGlobal",
    "MLPGlobal",
]

for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_default3",
        scores_dir="all_score_pointmae_default3",
        metrics_dir="all_metrics_pointmae_default3",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet",
    )
# Out:
# Running training for: PointNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet
# 100%|██████████| 180/180 [00:44<00:00,  4.03it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.94it/s]
# 100%|██████████| 200/200 [00:50<00:00,  3.97it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_default3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_default3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_default3\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_default3\normalization
# Using GPU
# 100%|██████████| 800/800 [23:42<00:00,  1.78s/it, train_loss=0.000431, val_loss=0.0168]
# Number of parameters: 153522.0
# Time elapsed: 1422.74 seconds
# Scores saved in: all_score_pointmae_default3\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [14:21<00:00,  1.08s/it, train_loss=0.000298, val_loss=0.0106]
# Number of parameters: 98266.0
# Time elapsed: 861.04 seconds
# Scores saved in: all_score_pointmae_default3\scarce\MLPGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_normalized3",
        scores_dir="all_score_pointmae_normalized3",
        metrics_dir="all_metrics_pointmae_normalized3",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_normalized/PointMAE_pretrain_normalized_features.parquet",
    )
# Out:
# Running training for: PointNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_normalized/PointMAE_pretrain_normalized_features.parquet
# 100%|██████████| 180/180 [00:30<00:00,  5.92it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.89it/s]
# 100%|██████████| 200/200 [00:33<00:00,  5.99it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_normalized3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_normalized3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_normalized3\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_normalized3\normalization
# Using GPU
# 100%|██████████| 800/800 [17:59<00:00,  1.35s/it, train_loss=0.000469, val_loss=0.0137]
# Number of parameters: 153522.0
# Time elapsed: 1079.92 seconds
# Scores saved in: all_score_pointmae_normalized3\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [14:22<00:00,  1.08s/it, train_loss=0.000328, val_loss=0.0142]
# Number of parameters: 98266.0
# Time elapsed: 862.51 seconds
# Scores saved in: all_score_pointmae_normalized3\scarce\MLPGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_default3",
        scores_dir="all_score_pointnet_default3",
        metrics_dir="all_metrics_pointnet_default3",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_default/cls_model_35_default_features.parquet",
    )
# Out:
# Running training for: PointNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/cls_model_35_default/cls_model_35_default_features.parquet
# 100%|██████████| 180/180 [00:30<00:00,  5.92it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.99it/s]
# 100%|██████████| 200/200 [00:33<00:00,  6.01it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_default3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_default3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_default3\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_default3\normalization
# Using GPU
# 100%|██████████| 800/800 [18:01<00:00,  1.35s/it, train_loss=0.00108, val_loss=0.0151]
# Number of parameters: 145330.0
# Time elapsed: 1081.52 seconds
# Scores saved in: all_score_pointnet_default3\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [14:19<00:00,  1.07s/it, train_loss=0.000263, val_loss=0.0099]
# Number of parameters: 90074.0
# Time elapsed: 859.68 seconds
# Scores saved in: all_score_pointnet_default3\scarce\MLPGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_normalized3",
        scores_dir="all_score_pointnet_normalized3",
        metrics_dir="all_metrics_pointnet_normalized3",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_normalized/cls_model_35_normalized_features.parquet",
    )
# Out:
# Running training for: PointNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/cls_model_35_normalized/cls_model_35_normalized_features.parquet
# 100%|██████████| 180/180 [00:30<00:00,  5.97it/s]
# 100%|██████████| 20/20 [00:03<00:00,  6.01it/s]
# 100%|██████████| 200/200 [00:32<00:00,  6.06it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_normalized3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_normalized3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_normalized3\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_normalized3\normalization
# Using GPU
# 100%|██████████| 800/800 [18:12<00:00,  1.37s/it, train_loss=0.000806, val_loss=0.0116]
# Number of parameters: 145330.0
# Time elapsed: 1092.42 seconds
# Scores saved in: all_score_pointnet_normalized3\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [14:23<00:00,  1.08s/it, train_loss=0.000447, val_loss=0.0131]
# Number of parameters: 90074.0
# Time elapsed: 863.47 seconds
# Scores saved in: all_score_pointnet_normalized3\scarce\MLPGlobal
