# %%
from main2 import run_training_pipeline

'''models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]'''
models_to_run = [
    "MLPGlobal",
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/Global_pointmae2_default",
        scores_dir="all_score_pointmae2_default_alpha_free",
        metrics_dir="all_metrics_pointmae2_default_alpha_free",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet",
    )
# Out:
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:13:16<00:00,  5.50s/it, train_loss=0.0003, val_loss=0.00216]
# Number of parameters: 29034.0
# Time elapsed: 4396.02 seconds
# Scores saved in: all_score_pointmae2_default_alpha_free\scarce\MLPGlobal
