# %%
from main2 import run_training_pipeline

'''models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]'''
models_to_run = [
    "MLP"
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP1_800",
        metrics_dir="metrics_baselineMLP1_800",
        param = 'params_pointnet', # same for MLP, we don t care 
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [14:41<00:00,  1.10s/it, train_loss=0.000136, val_loss=0.0131]
# Number of parameters: 19793.0
# Time elapsed: 881.96 seconds
# Scores saved in: scores_baselineMLP1_800\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP2_800",
        metrics_dir="metrics_baselineMLP2_800",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [14:43<00:00,  1.10s/it, train_loss=0.000146, val_loss=0.0118]
# Number of parameters: 19793.0
# Time elapsed: 883.36 seconds
# Scores saved in: scores_baselineMLP2_800\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP3_800",
        metrics_dir="metrics_baselineMLP3_800",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [18:28<00:00,  1.39s/it, train_loss=0.000145, val_loss=0.0126]
# Number of parameters: 19793.0
# Time elapsed: 1108.63 seconds
# Scores saved in: scores_baselineMLP3_800\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP4_800",
        metrics_dir="metrics_baselineMLP4_800",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [12:14<00:00,  1.09it/s, train_loss=0.000136, val_loss=0.0132]
# Number of parameters: 19793.0
# Time elapsed: 734.10 seconds
# Scores saved in: scores_baselineMLP4_800\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP5_800",
        metrics_dir="metrics_baselineMLP5_800",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [12:06<00:00,  1.10it/s, train_loss=0.000129, val_loss=0.012]
# Number of parameters: 19793.0
# Time elapsed: 726.51 seconds
# Scores saved in: scores_baselineMLP5_800\scarce\MLP

# %%
import json
import os

# Base directory where your metric folders are stored
base_dir = "."

# Loop over the 5 MLP result folders
for i in range(1, 6):
    json_path = os.path.join(base_dir, f"metrics_baselineMLP{i}_800", "scarce", "MLP", "MLP_log.json")
    
    try:
        with open(json_path, "r") as f:
            data = json.load(f)
        print(f"\n=== MLP{i} Results ===")
        print(json.dumps(data, indent=4))
    except FileNotFoundError:
        print(f"\n[Warning] File not found: {json_path}")
    except json.JSONDecodeError:
        print(f"\n[Error] Could not decode JSON in: {json_path}")
# Out:
# === MLP1 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 881.95822930336,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 800,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.0001356657303404063,
#     "val_loss": 0.013113051854379592
# }
#
# === MLP2 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 883.3568644523621,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 800,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.0001461612991988659,
#     "val_loss": 0.011763835092315275
# }
#
# === MLP3 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 1108.6311748027802,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 800,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.00014522986020892859,
#     "val_loss": 0.012577433584410755
# }
#
# === MLP4 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 734.0979011058807,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 800,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.00013599355588667095,
#     "val_loss": 0.013223637845512715
# }
#
# === MLP5 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 726.5124633312225,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 800,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.00012913247337564826,
#     "val_loss": 0.012006804815173383
# }

# %%
# Reference (paper): 1.13 ± 0.14 ×10⁻¹

import json, os, numpy as np, matplotlib.pyplot as plt

train, val = [], []
for i in range(1, 6):
    path = os.path.join(f"metrics_baselineMLP{i}_800", "scarce", "MLP", "MLP_log.json")
    with open(path) as f:
        data = json.load(f)
    train.append(data["train_loss"])
    val.append(data["val_loss"])

train, val = np.array(train), np.array(val)

mean_train, std_train = train.mean(), train.std(ddof=1)
mean_val, std_val = val.mean(), val.std(ddof=1)
cv_train = std_train / mean_train * 100
cv_val = std_val / mean_val * 100

print("=== Pressure Surface MSE Stability ===")
for i in range(5):
    print(f"MLP{i+1}: train={train[i]:.3e}, val={val[i]:.3e}")

print(f"\nTrain (scarce) mean={mean_train:.3e}, std={std_train:.3e}, Coef of variation={cv_train:.2f}%")
print(f"Val(scarce)   mean={mean_val:.3e}, std={std_val:.3e}, Coef of variation={cv_val:.2f}%")
print("\nReference (paper) for Full training set: 1.13 ± 0.14 ×10⁻¹  → CV ≈ 12.4%")

x = np.arange(1, 6)
plt.bar(x - 0.2, train, width=0.4, label="Train MSE")
plt.bar(x + 0.2, val, width=0.4, label="Val MSE")
plt.xlabel("MLP Run")
plt.ylabel("MSE")
plt.title("Pressure-Surface MSE per Run")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Pressure Surface MSE Stability ===
# MLP1: train=1.357e-04, val=1.311e-02
# MLP2: train=1.462e-04, val=1.176e-02
# MLP3: train=1.452e-04, val=1.258e-02
# MLP4: train=1.360e-04, val=1.322e-02
# MLP5: train=1.291e-04, val=1.201e-02
#
# Train (scarce) mean=1.384e-04, std=7.177e-06, Coef of variation=5.18%
# Val(scarce)   mean=1.254e-02, std=6.488e-04, Coef of variation=5.18%
#
# Reference (paper) for Full training set: 1.13 ± 0.14 ×10⁻¹  → CV ≈ 12.4%
