# %%
import torch
import numpy as np
import os.path as osp
from torch_geometric.loader import DataLoader
import random
import torch_geometric.nn as nng
import json
from dataset import Dataset
import os

# %%
dataset1 = torch.load('save_dataset/Global_pointnet2_default/train_dataset', map_location="cpu", weights_only=False)
print("Train:\n")
print(dataset1)
all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]
print(all_g1[:10])
# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]
print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])

print(" \n\n\n Loading normalization file...")
coef_norm = torch.load(
    'save_dataset/Global_pointnet2_default/normalization',
    map_location='cpu',
    weights_only=False
)

names = ["mean_x", "std_x", "mean_y", "std_y", "mean_g", "std_g"]

print("\n\n\n Normalization summary:")
for name, arr in zip(names, coef_norm):
    if arr is None:
        print(f"{name}: None")
    else:
        try:
            print(f"{name}: shape = {arr.shape}")
        except AttributeError:
            print(f"{name}: type = {type(arr)} (no shape attribute)")

print("\n\n\n Test::")
dataset1 = torch.load(
    'save_dataset/Global_pointnet2_default/test_dataset',
    map_location="cpu",
    weights_only=False
)
print(dataset1)

# ------------------------------------------------------
# 1) Empilement des g en [N, 1024]
# ------------------------------------------------------
all_g1 = torch.stack([data.g for data in dataset1], dim=0).float()  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.mean(dim=0)   # [1024]
g_std_dim1  = all_g1.std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())

print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])


print("\n\n\n Val::")
dataset1 = torch.load('save_dataset/Global_pointnet2_default/val_dataset', map_location="cpu", weights_only=False)
print(dataset1)

all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])
# Out:
# Train:
#
# ...

# %%
dataset1 = torch.load('save_dataset/Global_pointnet2_normalized/train_dataset', map_location="cpu", weights_only=False)
print("Train:\n")
print(dataset1)
all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]
print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])

print(" \n\n\n Loading normalization file...")
coef_norm = torch.load(
    'save_dataset/Global_pointnet2_normalized/normalization',
    map_location='cpu',
    weights_only=False
)

names = ["mean_x", "std_x", "mean_y", "std_y", "mean_g", "std_g"]

print("\n\n\n Normalization summary:")
for name, arr in zip(names, coef_norm):
    if arr is None:
        print(f"{name}: None")
    else:
        try:
            print(f"{name}: shape = {arr.shape}")
        except AttributeError:
            print(f"{name}: type = {type(arr)} (no shape attribute)")

print("\n\n\n Test::")
dataset1 = torch.load(
    'save_dataset/Global_pointnet2_normalized/test_dataset',
    map_location="cpu",
    weights_only=False
)
print(dataset1)

# ------------------------------------------------------
# 1) Empilement des g en [N, 1024]
# ------------------------------------------------------
all_g1 = torch.stack([data.g for data in dataset1], dim=0).float()  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.mean(dim=0)   # [1024]
g_std_dim1  = all_g1.std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())

print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])


print("\n\n\n Val::")
dataset1 = torch.load('save_dataset/Global_pointnet2_normalized/val_dataset', map_location="cpu", weights_only=False)
print(dataset1)

all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])
# Out:
# Train:
#
# ...

# %%
dataset1 = torch.load('save_dataset/Global_pointmae2_centered_Extruded/train_dataset', map_location="cpu", weights_only=False)
print("Train:\n")
print(dataset1)
all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]
print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])

print(" \n\n\n Loading normalization file...")
coef_norm = torch.load(
    'save_dataset/Global_pointmae2_centered_Extruded/normalization',
    map_location='cpu',
    weights_only=False
)

names = ["mean_x", "std_x", "mean_y", "std_y", "mean_g", "std_g"]

print("\n\n\n Normalization summary:")
for name, arr in zip(names, coef_norm):
    if arr is None:
        print(f"{name}: None")
    else:
        try:
            print(f"{name}: shape = {arr.shape}")
        except AttributeError:
            print(f"{name}: type = {type(arr)} (no shape attribute)")

print("\n\n\n Test::")
dataset1 = torch.load(
    'save_dataset/Global_pointmae2_centered_Extruded/test_dataset',
    map_location="cpu",
    weights_only=False
)
print(dataset1)

# ------------------------------------------------------
# 1) Empilement des g en [N, 1024]
# ------------------------------------------------------
all_g1 = torch.stack([data.g for data in dataset1], dim=0).float()  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.mean(dim=0)   # [1024]
g_std_dim1  = all_g1.std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())

print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])


print("\n\n\n Val::")
dataset1 = torch.load('save_dataset/Global_pointmae2_centered_Extruded/val_dataset', map_location="cpu", weights_only=False)
print(dataset1)

all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])
# Out:
# Train:
#
# ...

# %%
dataset1 = torch.load('save_dataset/Global_pointmae2_default/train_dataset', map_location="cpu", weights_only=False)
print("Train:\n")
print(dataset1)
all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]
print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])

print(" \n\n\n Loading normalization file...")
coef_norm = torch.load(
    'save_dataset/Global_pointmae2_default/normalization',
    map_location='cpu',
    weights_only=False
)

names = ["mean_x", "std_x", "mean_y", "std_y", "mean_g", "std_g"]

print("\n\n\n Normalization summary:")
for name, arr in zip(names, coef_norm):
    if arr is None:
        print(f"{name}: None")
    else:
        try:
            print(f"{name}: shape = {arr.shape}")
        except AttributeError:
            print(f"{name}: type = {type(arr)} (no shape attribute)")

print("\n\n\n Test::")
dataset1 = torch.load(
    'save_dataset/Global_pointmae2_default/test_dataset',
    map_location="cpu",
    weights_only=False
)
print(dataset1)

# ------------------------------------------------------
# 1) Empilement des g en [N, 1024]
# ------------------------------------------------------
all_g1 = torch.stack([data.g for data in dataset1], dim=0).float()  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.mean(dim=0)   # [1024]
g_std_dim1  = all_g1.std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())

print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])


print("\n\n\n Val::")
dataset1 = torch.load('save_dataset/Global_pointmae2_default/val_dataset', map_location="cpu", weights_only=False)
print(dataset1)

all_g1 = torch.stack([data.g for data in dataset1], dim=0)  # [N, 1024]

# mean and std per dimension
g_mean_dim1 = all_g1.float().mean(dim=0)   # [1024]
g_std_dim1  = all_g1.float().std(dim=0)    # [1024]

print("Mean per dimension shape:", g_mean_dim1.shape)
print("Std  per dimension shape:", g_std_dim1.shape)

print("mean Mean:", g_mean_dim1.mean())
print("mean Std:", g_std_dim1.mean())


print("First 20 mean values:", g_mean_dim1[:20])
print("First 20 std values:", g_std_dim1[:20])
# Out:
# Train:
#
# ...
