# %%
import torch
from models.NNGlobal import NNGlobal  # allowlist the class
from models.MLP import MLP
from models.GlobalFusion import GlobalFusion

# Allowlist NNGlobal so Torch will load it
torch.serialization.add_safe_globals([NNGlobal, MLP, GlobalFusion])

model_path = "all_metrics_pointmae/scarce/MLPGlobal/model"

# Load the full model object (safe since it's your own checkpoint)
model = torch.load(model_path, map_location="cpu", weights_only=False)

# Access the alpha parameter inside the GlobalFusion block:
alpha_value = model.fuse.alpha.item()

print("Learned α =", alpha_value)
# Out:
# Learned α = 0.0

# %%
import torch
from models.NNGlobal import NNGlobal  # allowlist the class
from models.MLP import MLP
from models.GlobalFusion import GlobalFusion

# Allowlist NNGlobal so Torch will load it
torch.serialization.add_safe_globals([NNGlobal, MLP, GlobalFusion])

model_path = "all_metrics_pointmae2_default2/scarce/GraphSAGEGlobal/model"

# Load the full model object (safe since it's your own checkpoint)
model = torch.load(model_path, map_location="cpu", weights_only=False)

# Access the alpha parameter inside the GlobalFusion block:
alpha_value = model.fuse.alpha.item()

print("Learned α =", alpha_value)
# Out:
# Learned α = -2.630093812942505
