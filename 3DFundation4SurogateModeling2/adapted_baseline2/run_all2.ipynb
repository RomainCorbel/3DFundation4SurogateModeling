# %%
from main2 import run_training_pipeline
models_to_run_global = [
    "GUNetGlobal",
    "GraphSAGEGlobal",
    "PointNetGlobal",
    "MLPGlobal",
]
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_centered3",
        scores_dir="all_score_pointnet_centered4",
        metrics_dir="all_metrics_pointnet_centered4",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_centered/cls_model_35_centered_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/cls_model_35_centered/cls_model_35_centered_features.parquet
# ...
# 100%|██████████| 200/200 [00:02<00:00, 74.39it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_centered3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_centered3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_centered3\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_centered3\normalization
# Using GPU
# ...

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_centered3",
        scores_dir="all_score_pointmae_centered4",
        metrics_dir="all_metrics_pointmae_centered4",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered/PointMAE_pretrain_centered_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered/PointMAE_pretrain_centered_features.parquet
# ...
# 100%|██████████| 200/200 [00:03<00:00, 62.19it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_centered3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_centered3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_centered3\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_centered3\normalization
# Using GPU
# ...
