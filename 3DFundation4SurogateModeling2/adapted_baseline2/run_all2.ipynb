# %%
from main2 import run_training_pipeline

'''models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]'''
models_to_run = [
    "GraphSAGEGlobal"
]

# %%
'''for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae",
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain/pointmae_features.parquet",
        scores_dir="scores_PointMAE",
        metrics_dir="metrics_PointMAE",
        param="params_pointmae",
    )'''
# Out:
# 'for model in models_to_run:\n    print(f"\nRunning training for: {model}\n")\n    run_training_pipeline(\n        model=model,\n        task="scarce",\n        dataset_save_dir="save_dataset/pointmae",\n        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain/pointmae_features.parquet",\n        scores_dir="scores_PointMAE",\n        metrics_dir="metrics_PointMAE",\n        param="params_pointmae",\n    )'

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet35",
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35/cls_model_35_features.parquet",
        scores_dir="scores_Point_NET35",
        metrics_dir="metrics_Point_NET35",
        param = 'params_pointnet',
    )
# Out:
# Running training for: GraphSAGEGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
#  23%|██▎       | 42/180 [00:06<00:20,  6.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 for model in models_to_run:
#       2     print(f"\nRunning training for: {model}\n")
# ----> 3     run_training_pipeline(
#       4         model=model,
#       5         task="scarce",
#       6         dataset_save_dir="save_dataset/pointnet35",
#       7         features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35/cls_model_35_features.parquet",
#       8         scores_dir="scores_Point_NET35",
#       9         metrics_dir="metrics_Point_NET35",
#      10         param = 'params_pointnet',
#      11     )
#
# ...
