# %%
from main2 import run_training_pipeline

models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae",
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain/pointmae_features.parquet",
        scores_dir="scores_PointMAE",
        metrics_dir="metrics_PointMAE",
        param="params_pointmae",
    )
# Out:
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [09:38<00:00,  1.45s/it, train_loss=0.00236, val_loss=0.0158]
# Number of parameters: 78145.0
# Time elapsed: 578.84 seconds
# Scores saved in: scores_PointMAE\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [10:06<00:00,  1.52s/it, train_loss=0.000357, val_loss=0.0134]
# Number of parameters: 22889.0
# Time elapsed: 606.07 seconds
# Scores saved in: scores_PointMAE\scarce\MLPGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [10:32<00:00,  1.59s/it, train_loss=0.000415, val_loss=0.0111]
# Number of parameters: 32105.0
# Time elapsed: 632.90 seconds
# Scores saved in: scores_PointMAE\scarce\GraphSAGEGlobal
#
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [28:00<00:00,  4.22s/it, train_loss=0.00112, val_loss=0.0231]
# Number of parameters: 68721.0
# Time elapsed: 1680.66 seconds
# Scores saved in: scores_PointMAE\scarce\GUNetGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [05:42<00:00,  1.16it/s, train_loss=0.000392, val_loss=0.0106]
# Number of parameters: 19793.0
# Time elapsed: 342.95 seconds
# Scores saved in: scores_PointMAE\scarce\MLP
#
# Running training for: PointNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [07:56<00:00,  1.20s/it, train_loss=0.00348, val_loss=0.0204]
# Number of parameters: 75049.0
# Time elapsed: 476.31 seconds
# Scores saved in: scores_PointMAE\scarce\PointNet
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [13:44<00:00,  2.07s/it, train_loss=0.000394, val_loss=0.0164]
# Number of parameters: 29009.0
# Time elapsed: 824.69 seconds
# Scores saved in: scores_PointMAE\scarce\GraphSAGE
#
# Running training for: GUNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [32:59<00:00,  4.97s/it, train_loss=0.000878, val_loss=0.00943]
# Number of parameters: 65625.0
# Time elapsed: 1979.08 seconds
# Scores saved in: scores_PointMAE\scarce\GUNet

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet",
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_15/cls_model_15_features.parquet",
        scores_dir="scores_Point_NET",
        metrics_dir="metrics_Point_NET",
        param = 'params_pointnet',
    )
# Out:
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [09:05<00:00,  1.37s/it, train_loss=0.00117, val_loss=0.0125]
# Number of parameters: 83265.0
# Time elapsed: 545.26 seconds
# Scores saved in: scores_Point_NET\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [07:08<00:00,  1.08s/it, train_loss=0.000366, val_loss=0.0221]
# Number of parameters: 28009.0
# Time elapsed: 428.40 seconds
# Scores saved in: scores_Point_NET\scarce\MLPGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [14:36<00:00,  2.20s/it, train_loss=0.000367, val_loss=0.0129]
# Number of parameters: 37225.0
# Time elapsed: 876.58 seconds
# Scores saved in: scores_Point_NET\scarce\GraphSAGEGlobal
#
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [33:20<00:00,  5.03s/it, train_loss=0.000662, val_loss=0.0136]
# Number of parameters: 73841.0
# Time elapsed: 2000.53 seconds
# Scores saved in: scores_Point_NET\scarce\GUNetGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [06:45<00:00,  1.02s/it, train_loss=0.000295, val_loss=0.019]
# Number of parameters: 19793.0
# Time elapsed: 405.32 seconds
# Scores saved in: scores_Point_NET\scarce\MLP
#
# Running training for: PointNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [08:44<00:00,  1.32s/it, train_loss=0.00165, val_loss=0.0113]
# Number of parameters: 75049.0
# Time elapsed: 524.24 seconds
# Scores saved in: scores_Point_NET\scarce\PointNet
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [13:53<00:00,  2.09s/it, train_loss=0.000343, val_loss=0.0145]
# Number of parameters: 29009.0
# Time elapsed: 833.44 seconds
# Scores saved in: scores_Point_NET\scarce\GraphSAGE
#
# Running training for: GUNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [32:54<00:00,  4.96s/it, train_loss=0.000788, val_loss=0.0178]
# Number of parameters: 65625.0
# Time elapsed: 1974.22 seconds
# Scores saved in: scores_Point_NET\scarce\GUNet
