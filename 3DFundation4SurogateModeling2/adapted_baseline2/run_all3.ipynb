# %%
from main2 import run_training_pipeline
models_to_run_global = [
    "GUNetGlobal",
    "GraphSAGEGlobal",
    "PointNetGlobal",
    "MLPGlobal",
]
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_centered_Extruded3",
        scores_dir="all_score_pointnet_centered_Extruded4",
        metrics_dir="all_metrics_pointnet_centered_Extruded4",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_centered_Extruded/cls_model_35_centered_Extruded_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/cls_model_35_centered_Extruded/cls_model_35_centered_Extruded_features.parquet
# ...
# 100%|██████████| 200/200 [00:00<00:00, 441.98it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_centered_Extruded3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_centered_Extruded3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_centered_Extruded3\test_dataset
# ...

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_normalized_Extruded3",
        scores_dir="all_score_pointnet_normalized_Extruded4",
        metrics_dir="all_metrics_pointnet_normalized_Extruded4",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_normalized_Extruded/cls_model_35_normalized_Extruded_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/cls_model_35_normalized_Extruded/cls_model_35_normalized_Extruded_features.parquet
# ...
# 100%|██████████| 200/200 [00:00<00:00, 249.98it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_normalized_Extruded3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_normalized_Extruded3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_normalized_Extruded3\test_dataset
# ...

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_centered_Extruded3",
        scores_dir="all_score_pointmae_centered_Extruded4",
        metrics_dir="all_metrics_pointmae_centered_Extruded4",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered_Extruded/PointMAE_pretrain_centered_Extruded_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered_Extruded/PointMAE_pretrain_centered_Extruded_features.parquet
# ...
# 100%|██████████| 200/200 [00:00<00:00, 404.73it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_centered_Extruded3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_centered_Extruded3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_centered_Extruded3\test_dataset
# ...

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_default_Extruded3",
        scores_dir="all_score_pointmae_default_Extruded4",
        metrics_dir="all_metrics_pointmae_default_Extruded4",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default_Extruded/PointMAE_pretrain_default_Extruded_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default_Extruded/PointMAE_pretrain_default_Extruded_features.parquet
# ...
# 100%|██████████| 200/200 [00:00<00:00, 442.34it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_default_Extruded3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_default_Extruded3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_default_Extruded3\test_dataset
# ...

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_normalized_Extruded3",
        scores_dir="all_score_pointmae_normalized_Extruded4",
        metrics_dir="all_metrics_pointmae_normalized_Extruded4",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_normalized_Extruded/PointMAE_pretrain_normalized_Extruded_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_normalized_Extruded/PointMAE_pretrain_normalized_Extruded_features.parquet
# ...
# 100%|██████████| 200/200 [00:00<00:00, 360.36it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_normalized_Extruded3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_normalized_Extruded3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointmae_normalized_Extruded3\test_dataset
# ...

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_default_Extruded3",
        scores_dir="all_score_pointnet_default_Extruded4",
        metrics_dir="all_metrics_pointnet_default_Extruded4",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_default_Extruded/cls_model_35_default_Extruded_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/cls_model_35_default_Extruded/cls_model_35_default_Extruded_features.parquet
# ...
# 100%|██████████| 200/200 [00:00<00:00, 354.90it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_default_Extruded3\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_default_Extruded3\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\pointnet_default_Extruded3\test_dataset
# ...
