# %%
from main2 import run_training_pipeline
models_to_run_local = [
    "GraphSAGE",
    "GUNet",
]

for model in models_to_run_local:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baseline3",
        scores_dir="all_score_baseline3",
        metrics_dir="all_metrics_baseline3",
        param = 'params_pointmae',
    )
# Out:
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [17:39<00:00,  1.32s/it, train_loss=0.000131, val_loss=0.0182]
# Number of parameters: 29009.0
# Time elapsed: 1059.36 seconds
# Scores saved in: all_score_baseline3\scarce\GraphSAGE
#
# Running training for: GUNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [45:32<00:00,  3.42s/it, train_loss=0.000395, val_loss=0.0157]
# Number of parameters: 65625.0
# Time elapsed: 2732.01 seconds
# Scores saved in: all_score_baseline3\scarce\GUNet

# %%
models_to_run_global = [
    "GUNetGlobal",
    "GraphSAGEGlobal",
]

for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_default3",
        scores_dir="all_score_pointmae_default3",
        metrics_dir="all_metrics_pointmae_default3",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [47:23<00:00,  3.55s/it, train_loss=0.00167, val_loss=0.0128]
# Number of parameters: 144098.0
# Time elapsed: 2843.78 seconds
# Scores saved in: all_score_pointmae_default3\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [21:31<00:00,  1.61s/it, train_loss=0.000929, val_loss=0.00727]
# Number of parameters: 107482.0
# Time elapsed: 1291.37 seconds
# Scores saved in: all_score_pointmae_default3\scarce\GraphSAGEGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointmae_normalized3",
        scores_dir="all_score_pointmae_normalized3",
        metrics_dir="all_metrics_pointmae_normalized3",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_normalized/PointMAE_pretrain_normalized_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [47:33<00:00,  3.57s/it, train_loss=0.000649, val_loss=0.011]
# Number of parameters: 144098.0
# Time elapsed: 2853.78 seconds
# Scores saved in: all_score_pointmae_normalized3\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [21:26<00:00,  1.61s/it, train_loss=0.000735, val_loss=0.0167]
# Number of parameters: 107482.0
# Time elapsed: 1286.70 seconds
# Scores saved in: all_score_pointmae_normalized3\scarce\GraphSAGEGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_default3",
        scores_dir="all_score_pointnet_default3",
        metrics_dir="all_metrics_pointnet_default3",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_default/cls_model_35_default_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [47:27<00:00,  3.56s/it, train_loss=0.000978, val_loss=0.0104]
# Number of parameters: 135906.0
# Time elapsed: 2847.95 seconds
# Scores saved in: all_score_pointnet_default3\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [21:29<00:00,  1.61s/it, train_loss=0.000326, val_loss=0.0215]
# Number of parameters: 99290.0
# Time elapsed: 1289.62 seconds
# Scores saved in: all_score_pointnet_default3\scarce\GraphSAGEGlobal

# %%
for model in models_to_run_global:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/pointnet_normalized3",
        scores_dir="all_score_pointnet_normalized3",
        metrics_dir="all_metrics_pointnet_normalized3",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_normalized/cls_model_35_normalized_features.parquet",
    )
# Out:
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [47:31<00:00,  3.56s/it, train_loss=0.000887, val_loss=0.0131]
# Number of parameters: 135906.0
# Time elapsed: 2851.35 seconds
# Scores saved in: all_score_pointnet_normalized3\scarce\GUNetGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [21:34<00:00,  1.62s/it, train_loss=0.000725, val_loss=0.0127]
# Number of parameters: 99290.0
# Time elapsed: 1294.02 seconds
# Scores saved in: all_score_pointnet_normalized3\scarce\GraphSAGEGlobal
