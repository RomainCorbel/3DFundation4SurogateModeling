# %%
from main2 import run_training_pipeline

'''models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]'''
models_to_run = [
    "MLPGlobal",
    "MLP",
    "GraphSAGEGlobal",
    "GraphSAGE"
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="full",
        dataset_save_dir="save_dataset/Global_pointnet2_default",
        scores_dir="all_score_pointnet2_default",
        metrics_dir="all_metrics_pointnet2_default",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_Default/cls_model_35_Default_features.parquet",
    )
# Out:
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [53:29<00:00,  4.01s/it, train_loss=0.000311, val_loss=0.00265]
# Number of parameters: 28009.0
# Time elapsed: 3209.45 seconds
# Scores saved in: all_score_pointnet2_default\full\MLPGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [50:36<00:00,  3.80s/it, train_loss=0.000323, val_loss=0.00284]
# Number of parameters: 19793.0
# Time elapsed: 3036.61 seconds
# Scores saved in: all_score_pointnet2_default\full\MLP
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:58:03<00:00,  8.85s/it, train_loss=0.000283, val_loss=0.00235]
# Number of parameters: 37225.0
# Time elapsed: 7083.80 seconds
# Scores saved in: all_score_pointnet2_default\full\GraphSAGEGlobal
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:53:13<00:00,  8.49s/it, train_loss=0.000304, val_loss=0.00301]
# Number of parameters: 29009.0
# Time elapsed: 6793.73 seconds
# Scores saved in: all_score_pointnet2_default\full\GraphSAGE

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="full",
        dataset_save_dir="save_dataset/Global_pointnet2_normalized",
        scores_dir="all_score_pointnet2_normalized",
        metrics_dir="all_metrics_pointnet2_normalized",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_35_normalized/cls_model_35_normalized_features.parquet",
    )
# Out:
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [54:13<00:00,  4.07s/it, train_loss=0.000309, val_loss=0.0042]
# Number of parameters: 28009.0
# Time elapsed: 3253.35 seconds
# Scores saved in: all_score_pointnet2_normalized\full\MLPGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [50:20<00:00,  3.78s/it, train_loss=0.000301, val_loss=0.00272]
# Number of parameters: 19793.0
# Time elapsed: 3020.51 seconds
# Scores saved in: all_score_pointnet2_normalized\full\MLP
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:57:51<00:00,  8.84s/it, train_loss=0.000262, val_loss=0.00282]
# Number of parameters: 37225.0
# Time elapsed: 7071.62 seconds
# Scores saved in: all_score_pointnet2_normalized\full\GraphSAGEGlobal
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:50:26<00:00,  8.28s/it, train_loss=0.000272, val_loss=0.00272]
# Number of parameters: 29009.0
# Time elapsed: 6626.81 seconds
# Scores saved in: all_score_pointnet2_normalized\full\GraphSAGE
