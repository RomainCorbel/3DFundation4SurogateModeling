# %%
from main2 import run_training_pipeline

models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/Global_pointmae2_centered_Extruded",
        scores_dir="all_score_test",
        metrics_dir="all_metrics_test",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered_Extruded/PointMAE_pretrain_centered_Extruded_features.parquet",
    )
# Out:
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [00:33<00:00,  5.57s/it, train_loss=0.0382, val_loss=0.227]
# Number of parameters: 153522.0
# Time elapsed: 33.43 seconds
# Scores saved in: all_score_test\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [00:26<00:00,  4.36s/it, train_loss=0.0174, val_loss=0.0525]
# Number of parameters: 98266.0
# Time elapsed: 26.16 seconds
# Scores saved in: all_score_test\scarce\MLPGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [00:48<00:00,  8.07s/it, train_loss=0.018, val_loss=0.0895]
# Number of parameters: 107482.0
# Time elapsed: 48.45 seconds
# Scores saved in: all_score_test\scarce\GraphSAGEGlobal
#
# Running training for: GUNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [01:51<00:00, 18.57s/it, train_loss=0.0269, val_loss=0.142]
# Number of parameters: 144098.0
# Time elapsed: 111.41 seconds
# Scores saved in: all_score_test\scarce\GUNetGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [00:24<00:00,  4.09s/it, train_loss=0.017, val_loss=0.0928]
# Number of parameters: 19793.0
# Time elapsed: 24.55 seconds
# Scores saved in: all_score_test\scarce\MLP
#
# Running training for: PointNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [00:31<00:00,  5.28s/it, train_loss=0.0796, val_loss=0.209]
# Number of parameters: 75049.0
# Time elapsed: 31.70 seconds
# Scores saved in: all_score_test\scarce\PointNet
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [00:45<00:00,  7.53s/it, train_loss=0.0172, val_loss=0.0934]
# Number of parameters: 29009.0
# Time elapsed: 45.21 seconds
# Scores saved in: all_score_test\scarce\GraphSAGE
#
# Running training for: GUNet
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 6/6 [01:50<00:00, 18.49s/it, train_loss=0.032, val_loss=0.176]
# Number of parameters: 65625.0
# Time elapsed: 110.95 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 for model in models_to_run:
#       2     print(f"\nRunning training for: {model}\n")
# ----> 3     run_training_pipeline(
#       4         model=model,
#       5         task="scarce",
#       6         dataset_save_dir="save_dataset/Global_pointmae2_centered_Extruded",
#       7         scores_dir="all_score_test",
#       8         metrics_dir="all_metrics_test",
#       9         param = 'params_pointmae',
#      10         features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered_Extruded/PointMAE_pretrain_centered_Extruded_features.parquet",
#      11     )
#
# File c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\main2.py:185, in run_training_pipeline(model, task, dataset_save_dir, scores_dir, metrics_dir, param, features_dir)
#     183 # ---------- Always compute and save scores ----------
#     184 s = args_task + '_test' if args_task != 'scarce' else 'full_test'
# --> 185 true_coefs, pred_mean, pred_std = metrics2.Results_test(
#     186     device, [models], [hparams], coef_norm,
#     187     path_in='../Dataset', path_out=scores_dir,
#     188     n_test=3, criterion='MSE', s=s, test_dataset = test_dataset
#     189 )
#     191 # Save into structured folder: scores/<task>/<model>
#     192 score_dir = os.path.join(scores_dir, args_task, args_model)
#
# File c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\metrics2.py:90, in Results_test(device, models_list, hparams_list, coef_norm, path_in, path_out, n_test, criterion, s, test_dataset)
#      88 for data in test_loader:
#      89     data = data.to(device)
# ---> 90     pred = model(data)
#      91     y = data.y
#      93     if pred.dim() == 1:
#
# File c:\Users\romai\anaconda3\envs\torch128.3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\romai\anaconda3\envs\torch128.3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\models\GUNet.py:189, in GUNet.forward(self, data)
#     187     z, edge_index = DownSample(id, z, edge_index, pos_x, self.pool[n], self.pool_ratio[n], self.list_r[n], self.max_neighbors)
#     188 else:
# --> 189     z, edge_index = DownSample(id, z, edge_index, pos_x, None, self.pool_ratio[n], self.list_r[n], self.max_neighbors)
#     190 edge_index_list.append(edge_index.clone())
#     192 z = self.down_layers[n + 1](z, edge_index)
#
# File c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\models\GUNet.py:22, in DownSample(id, x, edge_index, pos_x, pool, pool_ratio, r, max_neighbors)
#      19 pos_x = pos_x[id_sampled]
#      20 id.append(id_sampled)
# ---> 22 edge_index_sampled = nng.radius_graph(x = pos_x.detach(), r = r, loop = True, max_num_neighbors = max_neighbors)
#      24 return y, edge_index_sampled
#
# File c:\Users\romai\anaconda3\envs\torch128.3\Lib\site-packages\torch_geometric\nn\pool\__init__.py:295, in radius_graph(x, r, batch, loop, max_num_neighbors, flow, num_workers, batch_size)
#     292 if not torch_geometric.typing.WITH_TORCH_CLUSTER_BATCH_SIZE:
#     293     return torch_cluster.radius_graph(x, r, batch, loop, max_num_neighbors,
#     294                                       flow, num_workers)
# --> 295 return torch_cluster.radius_graph(x, r, batch, loop, max_num_neighbors,
#     296                                   flow, num_workers, batch_size)
#
# File c:\Users\romai\anaconda3\envs\torch128.3\Lib\site-packages\torch_cluster\radius.py:140, in radius_graph(x, r, batch, loop, max_num_neighbors, flow, num_workers, batch_size)
#     101 r"""Computes graph edges to all points within a given distance.
#     102
#     103 Args:
#    (...)    136     edge_index = radius_graph(x, r=1.5, batch=batch, loop=False)
#     137 """
#     139 assert flow in ['source_to_target', 'target_to_source']
# --> 140 edge_index = radius(x, x, r, batch, batch,
#     141                     max_num_neighbors,
#     142                     num_workers, batch_size, not loop)
#     143 if flow == 'source_to_target':
#     144     row, col = edge_index[1], edge_index[0]
#
# File c:\Users\romai\anaconda3\envs\torch128.3\Lib\site-packages\torch_cluster\radius.py:86, in radius(x, y, r, batch_x, batch_y, max_num_neighbors, num_workers, batch_size, ignore_same_index)
#      83     ptr_x = torch.bucketize(arange, batch_x)
#      84     ptr_y = torch.bucketize(arange, batch_y)
# ---> 86 return torch.ops.torch_cluster.radius(x, y, ptr_x, ptr_y, r,
#      87                                       max_num_neighbors, num_workers,
#      88                                       ignore_same_index)
#
# File c:\Users\romai\anaconda3\envs\torch128.3\Lib\site-packages\torch\_ops.py:1243, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1241 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1242     return _call_overload_packet_from_python(self, *args, **kwargs)
# -> 1243 return self._op(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
models_to_run = [
    "MLPGlobal",
    "MLP",
    "GraphSAGEGlobal",
    "GraphSAGE"
]

for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/Global_pointmae2_default",
        scores_dir="all_score_pointmae2_default2",
        metrics_dir="all_metrics_pointmae2_default2",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet",
    )
# Out:
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [52:30<00:00,  3.94s/it, train_loss=0.000768, val_loss=0.00312]
# Number of parameters: 98266.0
# Time elapsed: 3150.96 seconds
# Scores saved in: all_score_pointmae2_default2\scarce\MLPGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [46:45<00:00,  3.51s/it, train_loss=0.000333, val_loss=0.00252]
# Number of parameters: 19793.0
# Time elapsed: 2805.49 seconds
# Scores saved in: all_score_pointmae2_default2\scarce\MLP
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:48:40<00:00,  8.15s/it, train_loss=0.000748, val_loss=0.0031]
# Number of parameters: 107482.0
# Time elapsed: 6520.28 seconds
# Scores saved in: all_score_pointmae2_default2\scarce\GraphSAGEGlobal
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:38:49<00:00,  7.41s/it, train_loss=0.000281, val_loss=0.00222]
# Number of parameters: 29009.0
# Time elapsed: 5929.42 seconds
# Scores saved in: all_score_pointmae2_default2\scarce\GraphSAGE
