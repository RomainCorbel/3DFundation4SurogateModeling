# %%
from main2 import run_training_pipeline

'''models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]'''
models_to_run = [
    "MLPGlobal",
    "MLP",
    "GraphSAGEGlobal",
    "GraphSAGE"
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="full",
        dataset_save_dir="save_dataset/Global_pointmae2_centered_Extruded",
        scores_dir="all_score_pointmae2_centered_Extruded",
        metrics_dir="all_metrics_pointmae2_centered_Extruded",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered_Extruded/PointMAE_pretrain_centered_Extruded_features.parquet",
    )
# Out:
# Running training for: MLPGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_centered_Extruded/PointMAE_pretrain_centered_Extruded_features.parquet
# 100%|██████████| 720/720 [05:49<00:00,  2.06it/s]
# 100%|██████████| 80/80 [00:41<00:00,  1.92it/s]
# 100%|██████████| 200/200 [01:44<00:00,  1.91it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_centered_Extruded\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_centered_Extruded\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_centered_Extruded\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_centered_Extruded\normalization
# Using GPU
# 100%|██████████| 800/800 [1:04:26<00:00,  4.83s/it, train_loss=0.000378, val_loss=0.00395]
# Number of parameters: 29033.0
# Time elapsed: 3866.51 seconds
# Scores saved in: all_score_pointmae2_centered_Extruded\full\MLPGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [57:19<00:00,  4.30s/it, train_loss=0.000358, val_loss=0.00268]
# Number of parameters: 19793.0
# Time elapsed: 3439.90 seconds
# Scores saved in: all_score_pointmae2_centered_Extruded\full\MLP
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:48:39<00:00,  8.15s/it, train_loss=0.000266, val_loss=0.00207]
# Number of parameters: 38249.0
# Time elapsed: 6519.90 seconds
# Scores saved in: all_score_pointmae2_centered_Extruded\full\GraphSAGEGlobal
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:45:34<00:00,  7.92s/it, train_loss=0.000321, val_loss=0.00299]
# Number of parameters: 29009.0
# Time elapsed: 6334.59 seconds
# Scores saved in: all_score_pointmae2_centered_Extruded\full\GraphSAGE

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="full",
        dataset_save_dir="save_dataset/Global_pointmae2_default",
        scores_dir="all_score_pointmae2_default",
        metrics_dir="all_metrics_pointmae2_default",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet",
    )
# Out:
# Running training for: MLPGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain_default/PointMAE_pretrain_default_features.parquet
# 100%|██████████| 720/720 [02:03<00:00,  5.85it/s]
# 100%|██████████| 80/80 [00:13<00:00,  5.84it/s]
# 100%|██████████| 200/200 [00:34<00:00,  5.76it/s]
# [SAVE] Train -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_default\train_dataset
# [SAVE] Val   -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_default\val_dataset
# [SAVE] Test  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_default\test_dataset
# [SAVE] Norm  -> c:\Users\romai\Desktop\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointmae2_default\normalization
# Using GPU
# 100%|██████████| 800/800 [52:49<00:00,  3.96s/it, train_loss=0.00032, val_loss=0.00219]
# Number of parameters: 29033.0
# Time elapsed: 3169.06 seconds
# Scores saved in: all_score_pointmae2_default\full\MLPGlobal
#
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [49:04<00:00,  3.68s/it, train_loss=0.000287, val_loss=0.0019]
# Number of parameters: 19793.0
# Time elapsed: 2944.33 seconds
# Scores saved in: all_score_pointmae2_default\full\MLP
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:52:02<00:00,  8.40s/it, train_loss=0.000293, val_loss=0.00227]
# Number of parameters: 38249.0
# Time elapsed: 6722.41 seconds
# Scores saved in: all_score_pointmae2_default\full\GraphSAGEGlobal
#
# Running training for: GraphSAGE
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [1:43:49<00:00,  7.79s/it, train_loss=0.000261, val_loss=0.00231]
# Number of parameters: 29009.0
# Time elapsed: 6229.73 seconds
# Scores saved in: all_score_pointmae2_default\full\GraphSAGE
