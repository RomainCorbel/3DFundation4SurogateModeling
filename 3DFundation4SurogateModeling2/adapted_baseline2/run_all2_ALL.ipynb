# %%
from main2 import run_training_pipeline

models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/Global_pointmae",
        scores_dir="all_score_pointmae",
        metrics_dir="all_metrics_pointmae",
        param = 'params_pointmae',
        features_dir="../point_netANDpoint_MAE/extracted_features/PointMAE_pretrain/pointmae_features.parquet",
    )
# Out:
# Running training for: PointNetGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [15:50<00:00,  1.19s/it, train_loss=0.000803, val_loss=0.00937]
# Number of parameters: 84289.0
# Time elapsed: 950.28 seconds
# Scores saved in: all_score_pointmae\scarce\PointNetGlobal
#
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [13:04<00:00,  1.02it/s, train_loss=0.000158, val_loss=0.017]
# Number of parameters: 29033.0
# Time elapsed: 784.27 seconds
# Scores saved in: all_score_pointmae\scarce\MLPGlobal
#
# Running training for: GraphSAGEGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 800/800 [27:27<00:00,  2.06s/it, train_loss=0.000156, val_loss=0.0118]
# Number of parameters: 38249.0
# Time elapsed: 1647.40 seconds
# ...

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/Global_pointnet",
        scores_dir="all_score_pointnet",
        metrics_dir="all_metrics_pointnet",
        param = 'params_pointnet', # same for MLP, we don t care 
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_15/cls_model_15_features.parquet",
    )
# Out:
# Running training for: PointNetGlobal
#
# [BUILD] Building train_dataset, val_dataset, test_dataset, and normalization
# [INFO] Using global features from: ../point_netANDpoint_MAE/extracted_features/cls_model_15/cls_model_15_features.parquet
# ...
# 100%|██████████| 200/200 [01:12<00:00,  2.77it/s]
# [SAVE] Train -> c:\Users\romai\OneDrive\Bureau\EPFL\MA3\Project\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointnet\train_dataset
# [SAVE] Val   -> c:\Users\romai\OneDrive\Bureau\EPFL\MA3\Project\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointnet\val_dataset
# [SAVE] Test  -> c:\Users\romai\OneDrive\Bureau\EPFL\MA3\Project\3DFundation4SurogateModeling\3DFundation4SurogateModeling2\adapted_baseline2\save_dataset\Global_pointnet\test_dataset
# ...
