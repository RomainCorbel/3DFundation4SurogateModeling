# %%
from main2 import run_training_pipeline

'''models_to_run = [
    "PointNetGlobal",
    "MLPGlobal",
    "GraphSAGEGlobal",
    "GUNetGlobal",
    "MLP",
    "PointNet",
    "GraphSAGE",
    "GUNet",
]'''
models_to_run = [
    "MLP"
]

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP1",
        metrics_dir="metrics_baselineMLP1",
        param = 'params_pointnet', # same for MLP, we don t care 
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [05:51<00:00,  1.13it/s, train_loss=0.000355, val_loss=0.00946]
# Number of parameters: 19793.0
# Time elapsed: 351.49 seconds
# Scores saved in: scores_baselineMLP1\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP2",
        metrics_dir="metrics_baselineMLP2",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [06:01<00:00,  1.10it/s, train_loss=0.000325, val_loss=0.016]
# Number of parameters: 19793.0
# Time elapsed: 361.54 seconds
# Scores saved in: scores_baselineMLP2\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP3",
        metrics_dir="metrics_baselineMLP3",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [06:02<00:00,  1.10it/s, train_loss=0.000385, val_loss=0.00866]
# Number of parameters: 19793.0
# Time elapsed: 362.11 seconds
# Scores saved in: scores_baselineMLP3\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP4",
        metrics_dir="metrics_baselineMLP4",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [06:00<00:00,  1.10it/s, train_loss=0.000406, val_loss=0.0105]
# Number of parameters: 19793.0
# Time elapsed: 360.72 seconds
# Scores saved in: scores_baselineMLP4\scarce\MLP

# %%
for model in models_to_run:
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/baselineMLP",
        scores_dir="scores_baselineMLP5",
        metrics_dir="metrics_baselineMLP5",
        param = 'params_pointnet',
    )
# Out:
# Running training for: MLP
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
# 100%|██████████| 398/398 [05:15<00:00,  1.26it/s, train_loss=0.000302, val_loss=0.00813]
# Number of parameters: 19793.0
# Time elapsed: 315.30 seconds
# Scores saved in: scores_baselineMLP5\scarce\MLP

# %%
import json
import os

# Base directory where your metric folders are stored
base_dir = "."

# Loop over the 5 MLP result folders
for i in range(1, 6):
    json_path = os.path.join(base_dir, f"metrics_baselineMLP{i}", "scarce", "MLP", "MLP_log.json")
    
    try:
        with open(json_path, "r") as f:
            data = json.load(f)
        print(f"\n=== MLP{i} Results ===")
        print(json.dumps(data, indent=4))
    except FileNotFoundError:
        print(f"\n[Warning] File not found: {json_path}")
    except json.JSONDecodeError:
        print(f"\n[Error] Could not decode JSON in: {json_path}")
# Out:
# === MLP1 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 351.48854327201843,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 398,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.0003551358531694859,
#     "val_loss": 0.009456198540756303
# }
#
# === MLP2 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 361.5384216308594,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 398,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.00032482636743225157,
#     "val_loss": 0.016044152535032476
# }
#
# === MLP3 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 362.10906171798706,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 398,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.00038469405262731016,
#     "val_loss": 0.008661200488204488
# }
#
# === MLP4 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 360.7162928581238,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 398,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.0004060314386151731,
#     "val_loss": 0.010526582491365843
# }
#
# === MLP5 Results ===
# {
#     "task": "pressure_surface_only",
#     "loss": "MSE",
#     "nb_parameters": 19793.0,
#     "time_elapsed": 315.29751348495483,
#     "hparams": {
#         "encoder": [
#             7,
#             64,
#             64,
#             8
#         ],
#         "decoder": [
#             8,
#             64,
#             64,
#             1
#         ],
#         "nb_hidden_layers": 3,
#         "size_hidden_layers": 64,
#         "batch_size": 1,
#         "nb_epochs": 398,
#         "lr": 0.001,
#         "bn_bool": true,
#         "subsampling": 32000
#     },
#     "train_loss": 0.0003022176097147167,
#     "val_loss": 0.008132304257669603
# }

# %%
# Reference (paper): 1.13 ± 0.14 ×10⁻¹

import json, os, numpy as np, matplotlib.pyplot as plt

train, val = [], []
for i in range(1, 6):
    path = os.path.join(f"metrics_baselineMLP{i}", "scarce", "MLP", "MLP_log.json")
    with open(path) as f:
        data = json.load(f)
    train.append(data["train_loss"])
    val.append(data["val_loss"])

train, val = np.array(train), np.array(val)

mean_train, std_train = train.mean(), train.std(ddof=1)
mean_val, std_val = val.mean(), val.std(ddof=1)
cv_train = std_train / mean_train * 100
cv_val = std_val / mean_val * 100

print("=== Pressure Surface MSE Stability ===")
for i in range(5):
    print(f"MLP{i+1}: train={train[i]:.3e}, val={val[i]:.3e}")

print(f"\nTrain (scarce) mean={mean_train:.3e}, std={std_train:.3e}, Coef of variation={cv_train:.2f}%")
print(f"Val(scarce)   mean={mean_val:.3e}, std={std_val:.3e}, Coef of variation={cv_val:.2f}%")
print("\nReference (paper) for Full training set: 1.13 ± 0.14 ×10⁻¹  → CV ≈ 12.4%")

x = np.arange(1, 6)
plt.bar(x - 0.2, train, width=0.4, label="Train MSE")
plt.bar(x + 0.2, val, width=0.4, label="Val MSE")
plt.xlabel("MLP Run")
plt.ylabel("MSE")
plt.title("Pressure-Surface MSE per Run")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Pressure Surface MSE Stability ===
# MLP1: train=3.551e-04, val=9.456e-03
# MLP2: train=3.248e-04, val=1.604e-02
# MLP3: train=3.847e-04, val=8.661e-03
# MLP4: train=4.060e-04, val=1.053e-02
# MLP5: train=3.022e-04, val=8.132e-03
#
# Train (scarce) mean=3.546e-04, std=4.237e-05, Coef of variation=11.95%
# Val(scarce)   mean=1.056e-02, std=3.194e-03, Coef of variation=30.23%
#
# Reference (paper) for Full training set: 1.13 ± 0.14 ×10⁻¹  → CV ≈ 12.4%
