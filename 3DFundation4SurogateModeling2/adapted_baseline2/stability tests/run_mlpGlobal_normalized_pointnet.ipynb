# %%
from main2 import run_training_pipeline

models_to_run = [
    "MLPGlobal"
]

# %%
for model in models_to_run: # should be like 4
    print(f"\nRunning training for: {model}\n")
    run_training_pipeline(
        model=model,
        task="scarce",
        dataset_save_dir="save_dataset/Global_pointnet_GNormalized3",
        scores_dir="score_MLPGlobal_Gnormalized_pointnet5",
        metrics_dir="metrics_MLPGlobal_Gnormalized_pointnet5",
        param = 'params_pointnet',
        features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_15/cls_model_15_features.parquet",
    )
# Out:
# Running training for: MLPGlobal
#
# [CACHE] loading train_dataset, val_dataset, test_dataset, and normalization
# Using GPU
#   7%|▋         | 54/800 [00:51<11:55,  1.04it/s, train_loss=0.00884, val_loss=0.0353]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 for model in models_to_run: # should be like 4
#       2     print(f"\nRunning training for: {model}\n")
# ----> 3     run_training_pipeline(
#       4         model=model,
#       5         task="scarce",
#       6         dataset_save_dir="save_dataset/Global_pointnet_GNormalized3",
#       7         scores_dir="score_MLPGlobal_Gnormalized_pointnet5",
#       8         metrics_dir="metrics_MLPGlobal_Gnormalized_pointnet5",
#       9         param = 'params_pointnet',
#      10         features_dir="../point_netANDpoint_MAE/extracted_features/cls_model_15/cls_model_15_features.parquet",
# ...
